# %%
import pandas as pd
df=pd.read_excel("/content/GYM ACCESSORIES.CSV.xlsx")
df.head()
# Out:
#   ACCESSORY NAME        CATEGORY         BRAND  QUANTITY  PRICE(INR)  \
# 0      Treadmill          Cardio           HRX       3.0     35000.0
# 1    Bench press        Strength  LIFE FITNESS       1.0      9000.0
# 2      Dumbbells        Strength           HRX      10.0      1500.0
# 3        Barbell        Strength   REP FITNESS       5.0      3500.0
# 4    Chest press  Upper Strength  LIFE FITNESS       2.0      9000.0
#
#   PURCHASED DATE IN STOCK (YES/NO) WARRANTY PERIOD  USER RATING
# 0     2023-11-01                No           5 yrs          5.0
# 1     2024-02-15               Yes           2 yrs          4.0
# 2     2024-02-20               Yes        6 months          3.8
# 3     2024-05-15               Yes           2 yrs          4.8
# 4     2024-05-15               Yes           5 yrs          4.8

# %%
df["Total value"] = df["QUANTITY"] * df["PRICE(INR)"]
df[["ACCESSORY NAME","Total value"]]
# Out:
#     ACCESSORY NAME  Total value
# 0        Treadmill     105000.0
# 1      Bench press       9000.0
# 2        Dumbbells      15000.0
# 3          Barbell      17500.0
# 4      Chest press      18000.0
# 5      Multi press      88000.0
# 6    Leg extension      34000.0
# 7       ABS roller       3000.0
# 8    Smith machine     100000.0
# 9        Yoga mate       3000.0
# 10  Shoulder press     126000.0
# 11             NaN          NaN

# %%
df[df["IN STOCK (YES/NO)"]=="Yes"]
# Out:
#   ACCESSORY NAME         CATEGORY         BRAND  QUANTITY  PRICE(INR)  \
# 1    Bench press         Strength  LIFE FITNESS       1.0      9000.0
# 2      Dumbbells         Strength           HRX      10.0      1500.0
# 3        Barbell         Strength   REP FITNESS       5.0      3500.0
# 4    Chest press   Upper Strength  LIFE FITNESS       2.0      9000.0
# 7     ABS roller      Ab strength        GO FIT       2.0      1500.0
# 9      Yoga mate  Body flexibilty        REEBOK       5.0       600.0
#
#   PURCHASED DATE IN STOCK (YES/NO) WARRANTY PERIOD  USER RATING  Total value
# 1     2024-02-15               Yes           2 yrs          4.0       9000.0
# 2     2024-02-20               Yes        6 months          3.8      15000.0
# 3     2024-05-15               Yes           2 yrs          4.8      17500.0
# 4     2024-05-15               Yes           5 yrs          4.8      18000.0
# 7     2024-07-29               Yes           1 yrs          3.5       3000.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=df, x="CATEGORY", y="QUANTITY")
plt.title("Quantity by Category")
plt.xticks(rotation=45)
plt.show()

# %%
df.to_csv("updated_gym_data.csv", index=False)
files.download("updated_gym_data.csv")
